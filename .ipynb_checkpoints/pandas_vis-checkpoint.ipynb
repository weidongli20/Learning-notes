# %%
import pandas as pd

# %%
dataset = pd.read_csv("salaries.csv")
dataset
# Out:
#      1  Unnamed: 1       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0    2           1       Prof          B             19           18    Male
# 1    3           2       Prof          B             20           16    Male
# 2    4           3   AsstProf          B              4            3    Male
# 3    5           4       Prof          B             45           39    Male
# 4    6           5       Prof          B             40           41    Male
# 5    7           6  AssocProf          B              6            6    Male
# 6    8           7       Prof          B             30           23    Male
# 7    9           8       Prof          B             45           45    Male
# 8   10           9       Prof          B             21           20    Male
# 9   11          10       Prof          B             18           18  Female
# 10  12          11  AssocProf          B             12            8    Male
# 11  13          12   AsstProf          B              7            2    Male
# 12  14          13   AsstProf          B              1            1    Male
# 13  15          14   AsstProf          B              2            0    Male
# 14  16          15       Prof          B             20           18    Male
# 15  17          16       Prof          B             12            3    Male
# 16  18          17       Prof          B             19           20    Male
# 17  19          18       Prof          A             38           34    Male
# 18  20          19       Prof          A             37           23    Male
# 19  21          20       Prof          A             39           36  Female
# 20  22          21       Prof          A             31           26    Male
# 21  23          22       Prof          A             36           31    Male
# 22  24          23       Prof          A             34           30    Male
# 23  25          24       Prof          A             24           19    Male
#
#     salary
# 0   139750
# 1   173200
# 2    79750
# 3   115000
# 4   141500
# 5    97000
# 6   175000
# 7   147765
# 8   119250
# 9   129000
# 10  119800
# 11   79800
# 12   77700
# 13   78000
# 14  104800
# 15  117150
# 16  101000
# 17  103450
# 18  124750
# 19  137000
# 20   89565
# 21  102580
# 22   93904
# 23  113068

# %%
dataset.rename(columns={'yrs.since.phd': 'phd', 'yrs.service': 'service'}, inplace='True')
dataset.head()
# Out:
#    1  Unnamed: 1      rank discipline  phd  service   sex  salary
# 0  2           1      Prof          B   19       18  Male  139750
# 1  3           2      Prof          B   20       16  Male  173200
# 2  4           3  AsstProf          B    4        3  Male   79750
# 3  5           4      Prof          B   45       39  Male  115000
# 4  6           5      Prof          B   40       41  Male  141500

# %%
rank = dataset['rank']
discipline = dataset['discipline']
phd = dataset['phd']
service = dataset['service']
sex = dataset['sex']
salary = dataset['salary']
dataset.head()
# Out:
#    1  Unnamed: 1      rank discipline  phd  service   sex  salary
# 0  2           1      Prof          B   19       18  Male  139750
# 1  3           2      Prof          B   20       16  Male  173200
# 2  4           3  AsstProf          B    4        3  Male   79750
# 3  5           4      Prof          B   45       39  Male  115000
# 4  6           5      Prof          B   40       41  Male  141500

# %%
dataset[["rank", "discipline","phd","service", "sex", "salary"]].plot()
# Out:
# <AxesSubplot:>

# %%
dataset[["phd","service"]].plot()
# Out:
# <AxesSubplot:>

# %%
dataset1 = dataset.groupby(['service']).sum()
dataset1.sort_values("salary", ascending = False, inplace=True)
dataset1.head()
# Out:
#           1  Unnamed: 1  phd  salary
# service
# 18       29          26   57  373550
# 23       28          26   67  299750
# 20       28          26   40  220250
# 3        21          19   16  196900
# 16        3           2   20  173200

# %%
dataset1["salary"].plot.bar()
# Out:
# <AxesSubplot:xlabel='service'>

# %%
dataset[[ 'phd', 'service' ]].head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
dataset[['phd', 'service']].head(10).plot.bar(title="Ph.D. Vs Service\n 2018")
# Out:
# <AxesSubplot:title={'center':'Ph.D. Vs Service\n 2018'}>

# %%
dataset[['phd', 'service']].head(10).plot.bar(title="Ph.D. Vs Service\n 2018" , color=['g','red'])
# Out:
# <AxesSubplot:title={'center':'Ph.D. Vs Service\n 2018'}>

# %%
dataset["salary"].head(10).plot.pie(autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='salary'>

# %%
dataset[["phd","salary"]].head(100).plot.box()
# Out:
# <AxesSubplot:>

# %%
dataset[["phd","service"]].plot.box()
# Out:
# <AxesSubplot:>

# %%
dataset["salary"].head(20).plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataset.plot(kind='scatter', x='phd', y='service',
             title='Popuation vs area and density\n 2018', s=15)
# Out:
# <AxesSubplot:title={'center':'Popuation vs area and density\n 2018'}, xlabel='phd', ylabel='service'>
